# %%
# importing libraries
import pandas as pd

# %% [markdown]
# # Dataset 1 - complexes.csv

# %%
df1 = pd.read_csv("complexes.csv")

# %%
# first few rows
df1.head()
# Out:
#         complex_id                           complex_name
# 0   sr:complex:705                               Nacional
# 1  sr:complex:1078                     Estadio la Cartuja
# 2  sr:complex:1495                            Sibur Arena
# 3  sr:complex:2375             Complexo de Tenis do Jamor
# 4  sr:complex:4032  Shree Shiv Chhatrapati Sports Complex

# %%
# Basic information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   complex_id    761 non-null    object
#  1   complex_name  761 non-null    object
# dtypes: object(2)
# memory usage: 12.0+ KB

# %%
# check missing values
df1.isnull().sum()
# Out:
# complex_id      0
# complex_name    0
# dtype: int64

# %%
# check duplicates
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Save clean csv

# %%
df1.to_csv('clean_complexes.csv', index=False)

# %% [markdown]
# ### load the clean complexes

# %%
clean_df = pd.read_csv("clean_complexes.csv")

# %%
clean_df.head()
# Out:
#         complex_id                           complex_name
# 0   sr:complex:705                               Nacional
# 1  sr:complex:1078                     Estadio la Cartuja
# 2  sr:complex:1495                            Sibur Arena
# 3  sr:complex:2375             Complexo de Tenis do Jamor
# 4  sr:complex:4032  Shree Shiv Chhatrapati Sports Complex

# %% [markdown]
# #### Data is perfectly clean, no cleaning needed here

# %% [markdown]
# # Dataset 2 - venues.csv

# %%
df2 = pd.read_csv("venues.csv")

# %%
df2.head()
# Out:
#          venue_id      venue_name              city             country  \
# 0  sr:venue:70045  Cancha Central          Santiago               CHILE
# 1  sr:venue:74856    Centre Court           Seville               SPAIN
# 2  sr:venue:74858       Court One           Seville               SPAIN
# 3  sr:venue:62149     Sibur Arena  Saint Petersburg  RUSSIAN FEDERATION
# 4   sr:venue:1500    CENTER COURT  Saint Petersburg  RUSSIAN FEDERATION
#
#   country_code          timezone       complex_id
# 0          CHL  America/Santiago   sr:complex:705
# 1          ESP     Europe/Madrid  sr:complex:1078
# 2          ESP     Europe/Madrid  sr:complex:1078
# 3          RUS     Europe/Moscow  sr:complex:1495
# 4          RUS     Europe/Moscow  sr:complex:1495

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3913 entries, 0 to 3912
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   venue_id      3913 non-null   object
#  1   venue_name    3913 non-null   object
#  2   city          3913 non-null   object
#  3   country       3913 non-null   object
#  4   country_code  3913 non-null   object
#  5   timezone      3913 non-null   object
#  6   complex_id    3913 non-null   object
# dtypes: object(7)
# memory usage: 214.1+ KB

# %%
df2.shape
# Out:
# (3913, 7)

# %%
df2.describe()
# Out:
#               venue_id venue_name    city        country country_code  \
# count             3913       3913    3913           3913         3913
# unique            3913       1081     435             76           76
# top     sr:venue:70045    Court 1  London  UNITED STATES          USA
# freq                 1        331      49            633          633
#
#                 timezone        complex_id
# count               3913              3913
# unique                90               603
# top     America/New_York  sr:complex:33222
# freq                 324                29

# %%
df2.columns.tolist()
# Out:
# ['venue_id',
#  'venue_name',
#  'city',
#  'country',
#  'country_code',
#  'timezone',
#  'complex_id']

# %%
df2.isnull().sum()
# Out:
# venue_id        0
# venue_name      0
# city_name       0
# country_name    0
# country_code    0
# timezone        0
# complex_id      0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Transformation - fix the column names(different from schema)

# %%
df2.rename(columns={
    'city': 'city_name',
    'country': 'country_name'
}, inplace=True)

# %%
df2.columns.tolist()
# Out:
# ['venue_id',
#  'venue_name',
#  'city_name',
#  'country_name',
#  'country_code',
#  'timezone',
#  'complex_id']

# %%
# Save the clean file
df2.to_csv("clean_venues.csv", index = False)

# %%
# load the clean venues.csv
clean_df = pd.read_csv("clean_venues.csv")

# %%
clean_df.head()
# Out:
#          venue_id      venue_name         city_name        country_name  \
# 0  sr:venue:70045  Cancha Central          Santiago               CHILE
# 1  sr:venue:74856    Centre Court           Seville               SPAIN
# 2  sr:venue:74858       Court One           Seville               SPAIN
# 3  sr:venue:62149     Sibur Arena  Saint Petersburg  RUSSIAN FEDERATION
# 4   sr:venue:1500    CENTER COURT  Saint Petersburg  RUSSIAN FEDERATION
#
#   country_code          timezone       complex_id
# 0          CHL  America/Santiago   sr:complex:705
# 1          ESP     Europe/Madrid  sr:complex:1078
# 2          ESP     Europe/Madrid  sr:complex:1078
# 3          RUS     Europe/Moscow  sr:complex:1495
# 4          RUS     Europe/Moscow  sr:complex:1495

# %%
df2.columns.tolist()
# Out:
# ['venue_id',
#  'venue_name',
#  'city_name',
#  'country_name',
#  'country_code',
#  'timezone',
#  'complex_id']

# %% [markdown]
# #### No nulls and duplicates in the venues.csv. Performed data transformation by fixing the name of columns like city and country. taht means data is now perfectly clean and ready to give business anlysis.
