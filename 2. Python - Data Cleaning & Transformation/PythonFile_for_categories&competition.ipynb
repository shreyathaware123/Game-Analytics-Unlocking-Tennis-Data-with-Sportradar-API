# %%
import pandas as pd

# %% [markdown]
# # 1. categories.csv

# %%
df1 = pd.read_csv("categories.csv")

# %%
# first few rows
df1.head()
# Out:
#        category_id category_name
# 0  sr:category:181    Hopman Cup
# 1    sr:category:3           ATP
# 2   sr:category:72    Challenger
# 3    sr:category:6           WTA
# 4   sr:category:76     Davis Cup

# %%
# rows and columns
df1.shape
# Out:
# (18, 2)

# %%
# dataset basic information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    18 non-null     object
#  1   category_name  18 non-null     object
# dtypes: object(2)
# memory usage: 416.0+ bytes

# %%
# Statistical information
df1.describe()
# Out:
#             category_id category_name
# count                18            18
# unique               18            18
# top     sr:category:181    Hopman Cup
# freq                  1             1

# %%
df1.isnull().sum()
# Out:
# category_id      0
# category_name    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Saving clean csv

# %%
df1.to_csv("clean_categories.csv", index = False)

# %% [markdown]
# ### Loaded clean categories csv

# %%
clean_csv = pd.read_csv("clean_categories.csv")
clean_csv.head()
# Out:
#        category_id category_name
# 0  sr:category:181    Hopman Cup
# 1    sr:category:3           ATP
# 2   sr:category:72    Challenger
# 3    sr:category:6           WTA
# 4   sr:category:76     Davis Cup

# %% [markdown]
# ###  # categories.csv is perfectly clean and ready for insights

# %% [markdown]
# # 2. competitions.csv

# %%
df2 = pd.read_csv("competitions.csv")

# %%
df2.head()
# Out:
#         competition_id                   competition_name     type gender  \
# 0   sr:competition:620                         Hopman Cup    mixed  mixed
# 1   sr:competition:660                     World Team Cup    mixed    men
# 2   sr:competition:990         ATP Challenger Tour Finals  singles    men
# 3  sr:competition:1207  Championship International Series  singles  women
# 4  sr:competition:2100                          Davis Cup    mixed    men
#
#        category_id category_name
# 0  sr:category:181    Hopman Cup
# 1    sr:category:3           ATP
# 2   sr:category:72    Challenger
# 3    sr:category:6           WTA
# 4   sr:category:76     Davis Cup

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6490 entries, 0 to 6489
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competition_id    6490 non-null   object
#  1   competition_name  6490 non-null   object
#  2   type              6490 non-null   object
#  3   gender            6488 non-null   object
#  4   category_id       6490 non-null   object
#  5   category_name     6490 non-null   object
# dtypes: object(6)
# memory usage: 304.3+ KB

# %%
df2.shape
# Out:
# (6490, 6)

# %%
df2.columns
# Out:
# Index(['competition_id', 'competition_name', 'type', 'gender', 'category_id',
#        'category_name'],
#       dtype='object')

# %%
df2.describe()
# Out:
#             competition_id competition_name     type gender      category_id  \
# count                 6490             6490     6490   6488             6490
# unique                6490             6490        4      3               18
# top     sr:competition:620       Hopman Cup  singles    men  sr:category:785
# freq                     1                1     3475   3715             2198
#
#        category_name
# count           6490
# unique            18
# top          ITF Men
# freq            2198

# %% [raw]
# # Total count - 6490
# # Gender showing 2 missing values - need to clean

# %%
df2['gender']
# Out:
# 0       mixed
# 1         men
# 2         men
# 3       women
# 4         men
#         ...
# 6485      men
# 6486    women
# 6487    women
# 6488    women
# 6489    women
# Name: gender, Length: 6490, dtype: object

# %%
df2[df2['gender'].isnull()]
# Out:
#             competition_id     competition_name     type gender  \
# 6376  sr:competition:49660  Battle of the Sexes  singles    NaN
# 6389  sr:competition:49854   Miami Invitational  singles    NaN
#
#          category_id category_name
# 6376  sr:category:79    Exhibition
# 6389  sr:category:79    Exhibition

# %% [markdown]
# ### Filling missing values in gender as 'Unknown'

# %%
df2['gender'].fillna('Unknown', inplace=True)

# %%
df2['gender']
# Out:
# 0       mixed
# 1         men
# 2         men
# 3       women
# 4         men
#         ...
# 6485      men
# 6486    women
# 6487    women
# 6488    women
# 6489    women
# Name: gender, Length: 6490, dtype: object

# %%
# verify

df2['gender'].isnull().sum()
# Out:
# 0

# %%
# Now no missing values in gender

# %%
df2.isnull().sum()
# Out:
# competition_id      0
# competition_name    0
# type                0
# gender              0
# category_id         0
# category_name       0
# dtype: int64

# %%
# No missing values in dataset.

# %% [raw]
# # Need to remove the category_name column:
#
#     1. Because it already exist in categories table
#     2. by keeping in both csv shows data redundancy
#     3. in sql, we need to join using category id

# %%
df2.columns
# Out:
# Index(['competition_id', 'competition_name', 'type', 'gender', 'category_id',
#        'category_name'],
#       dtype='object')

# %% [markdown]
# ### Removing category_name column

# %%
df2 = df2[['competition_id', 'competition_name', 'type', 'gender', 'category_id']]

# %%
df2.head()
# Out:
#         competition_id                   competition_name     type gender  \
# 0   sr:competition:620                         Hopman Cup    mixed  mixed
# 1   sr:competition:660                     World Team Cup    mixed    men
# 2   sr:competition:990         ATP Challenger Tour Finals  singles    men
# 3  sr:competition:1207  Championship International Series  singles  women
# 4  sr:competition:2100                          Davis Cup    mixed    men
#
#        category_id
# 0  sr:category:181
# 1    sr:category:3
# 2   sr:category:72
# 3    sr:category:6
# 4   sr:category:76

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6490 entries, 0 to 6489
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competition_id    6490 non-null   object
#  1   competition_name  6490 non-null   object
#  2   type              6490 non-null   object
#  3   gender            6490 non-null   object
#  4   category_id       6490 non-null   object
# dtypes: object(5)
# memory usage: 253.6+ KB

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###  # competitions.csv is perfectly clean and ready for insights

# %%
# Save clean file
df2.to_csv('clean_competitions.csv', index=False)

# %%
# load the clean competitions.csv

clean_df = pd.read_csv("clean_competitions.csv")
clean_df.head()
# Out:
#         competition_id                   competition_name     type gender  \
# 0   sr:competition:620                         Hopman Cup    mixed  mixed
# 1   sr:competition:660                     World Team Cup    mixed    men
# 2   sr:competition:990         ATP Challenger Tour Finals  singles    men
# 3  sr:competition:1207  Championship International Series  singles  women
# 4  sr:competition:2100                          Davis Cup    mixed    men
#
#        category_id
# 0  sr:category:181
# 1    sr:category:3
# 2   sr:category:72
# 3    sr:category:6
# 4   sr:category:76
